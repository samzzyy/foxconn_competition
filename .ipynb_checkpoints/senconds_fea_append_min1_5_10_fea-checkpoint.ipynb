# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
fea_second_dire="../zd"
fea_minute_dire="feature"
file_index=1

# %%
df_fea_min = pd.read_csv(os.path.join(fea_minute_dire,"train_min_0"+str(file_index)+"_feature_add5min.csv"))
df_fea_min.drop(columns=['residual_life'],inplace=True)
df_fea_second=pd.read_csv(os.path.join(fea_second_dire,str(file_index)+"_feature.csv"))

print(df_fea_min.columns,'\n',df_fea_min.shape)
print(df_fea_second.columns,'\n',df_fea_second.shape)
df_feature=pd.merge(df_fea_second,df_fea_min,on=['tool_age'])
print(df_feature.columns,df_feature.shape)
print(df_feature.head(10))
df_feature.to_csv(os.path.join(fea_minute_dire,str(file_index)+"_feature.csv"),index=False)
# Out:
# Index(['mean_spindel', 'var_spindel', 'range_spindel', 'c_mean', 'c_abs_mean',
#        'c_var', 'c_abs_var', 'c_range', 'c_abs_range', 'v_mean', 'v_abs_mean',
#        'v_var', 'v_abs_var', 'v_range', 'v_abs_range', 'tool_age',
#        's_mean_min5_mean', 'c_mean_min5_abs_mean', 'v_mean_min5_mean',
#        's_mean_min5_var', 'c_mean_min5_abs_var', 'v_mean_min5_var',
#        's_mean_min5_range', 'c_mean_min5_abs_range', 'v_mean_min5_range',
#        's_mean_min5_diff', 'c_mean_min5_abs_diff', 'v_mean_min5_diff',
#        's_mean_min10_mean', 'c_mean_min10_abs_mean', 'v_mean_min10_mean',
#        's_mean_min10_var', 'c_mean_min10_abs_var', 'v_mean_min10_var',
#        's_mean_min10_range', 'c_mean_min10_abs_range', 'v_mean_min10_range',
#        's_mean_min10_diff', 'c_mean_min10_abs_diff', 'v_mean_min5_diff.1'],
#       dtype='object')
#  (48, 40)
# Index(['v1_absmean', 'v2_absmean', 'v3_absmean', 'c_absmean', 'v1_absmedia',
#        'v2_absmedia', 'v3_absmedia', 'c_absmedia', 'v1_absmode', 'v2_absmode',
#        'v3_absmode', 'c_absmode', 'v1_absrange', 'v2_absrange', 'v3_absrange',
#        'c_absrange', 'v1_absstdn', 'v2_absstdn', 'v3_absstdn', 'c_absstdn',
#        'v1_absvar', 'v2_absvar', 'v3_absvar', 'c_absvar', 'v1_maxvalue',
#        'v2_maxvalue', 'v3_maxvalue', 'c_maxvalue', 'v1_absmax', 'v2_absmax',
#        'v3_absmax', 'c_absmax', 'v1_minvalue', 'v2_minvalue', 'v3_minvalue',
#        'c_minvalue', 'v1_absmin', 'v2_absmin', 'v3_absmin', 'c_absmin',
#        'residual_life', 'tool_age'],
#       dtype='object')
#  (2805, 42)
# Index(['v1_absmean', 'v2_absmean', 'v3_absmean', 'c_absmean', 'v1_absmedia',
#        'v2_absmedia', 'v3_absmedia', 'c_absmedia', 'v1_absmode', 'v2_absmode',
#        'v3_absmode', 'c_absmode', 'v1_absrange', 'v2_absrange', 'v3_absrange',
#        'c_absrange', 'v1_absstdn', 'v2_absstdn', 'v3_absstdn', 'c_absstdn',
#        'v1_absvar', 'v2_absvar', 'v3_absvar', 'c_absvar', 'v1_maxvalue',
#        'v2_maxvalue', 'v3_maxvalue', 'c_maxvalue', 'v1_absmax', 'v2_absmax',
#        'v3_absmax', 'c_absmax', 'v1_minvalue', 'v2_minvalue', 'v3_minvalue',
#        'c_minvalue', 'v1_absmin', 'v2_absmin', 'v3_absmin', 'c_absmin',
#        'residual_life', 'tool_age', 'mean_spindel', 'var_spindel',
#        'range_spindel', 'c_mean', 'c_abs_mean', 'c_var', 'c_abs_var',
#        'c_range', 'c_abs_range', 'v_mean', 'v_abs_mean', 'v_var', 'v_abs_var',
#        'v_range', 'v_abs_range', 's_mean_min5_mean', 'c_mean_min5_abs_mean',
#        'v_mean_min5_mean', 's_mean_min5_var', 'c_mean_min5_abs_var',
#        'v_mean_min5_var', 's_mean_min5_range', 'c_mean_min5_abs_range',
#        'v_mean_min5_range', 's_mean_min5_diff', 'c_mean_min5_abs_diff',
#        'v_mean_min5_diff', 's_mean_min10_mean', 'c_mean_min10_abs_mean',
#        'v_mean_min10_mean', 's_mean_min10_var', 'c_mean_min10_abs_var',
#        'v_mean_min10_var', 's_mean_min10_range', 'c_mean_min10_abs_range',
#        'v_mean_min10_range', 's_mean_min10_diff', 'c_mean_min10_abs_diff',
#        'v_mean_min5_diff.1'],
#       dtype='object') (2805, 81)
#    v1_absmean  v2_absmean  v3_absmean  c_absmean  v1_absmedia  v2_absmedia  \
# 0   32.489325   31.878479   32.187080   0.904959    36.335218    35.488063
# 1   32.478693   31.715624   32.291805   1.013564    36.397761    35.290217
# 2   32.317294   31.751647   32.561771   1.026486    36.086130    35.231043
# 3   32.178111   31.818503   32.528474   1.051570    35.962537    35.353539
# 4   32.213591   32.056976   32.332831   1.029254    35.818442    35.836776
# 5   32.261494   32.055812   32.159870   1.025436    36.129101    35.754217
# 6   32.482977   31.869256   32.179660   1.044487    36.353846    35.485373
# 7   32.510752   31.738131   32.284351   1.024289    36.483826    35.392007
# 8   32.359002   31.710283   32.468762   1.028021    36.095923    35.071528
# 9   32.336004   32.031020   32.557021   1.054012    36.003624    35.636293
#
#    v3_absmedia  c_absmedia  v1_absmode  v2_absmode         ...          \
# 0    35.691554    0.756900   43.933622    0.824328         ...
# 1    36.085805    0.861385   17.094448    0.344016         ...
# 2    36.295133    0.871788    0.848176   49.406018         ...
# 3    36.292721    0.906956   44.579432    0.899672         ...
# 4    35.967119    0.877583   40.403604    0.243957         ...
# 5    35.790584    0.874749    0.347860   41.009087         ...
# 6    35.784492    0.893836    0.889024    2.602364         ...
# 7    36.035605    0.871516    0.072352    2.548571         ...
# 8    36.205803    0.874804   35.745604    0.135300         ...
# 9    36.226267    0.901222   48.712028   39.675117         ...
#
#    v_mean_min10_mean  s_mean_min10_var  c_mean_min10_abs_var  \
# 0           3.254828          0.083554              0.147075
# 1           3.254828          0.083554              0.147075
# 2           3.254828          0.083554              0.147075
# 3           3.254828          0.083554              0.147075
# 4           3.254828          0.083554              0.147075
# 5           3.254828          0.083554              0.147075
# 6           3.254828          0.083554              0.147075
# 7           3.254828          0.083554              0.147075
# 8           3.254828          0.083554              0.147075
# 9           3.254828          0.083554              0.147075
#
#    v_mean_min10_var  s_mean_min10_range  c_mean_min10_abs_range  \
# 0        105.939085            0.914081                1.212743
# 1        105.939085            0.914081                1.212743
# 2        105.939085            0.914081                1.212743
# 3        105.939085            0.914081                1.212743
# 4        105.939085            0.914081                1.212743
# 5        105.939085            0.914081                1.212743
# 6        105.939085            0.914081                1.212743
# 7        105.939085            0.914081                1.212743
# 8        105.939085            0.914081                1.212743
# 9        105.939085            0.914081                1.212743
#
#    v_mean_min10_range  s_mean_min10_diff  c_mean_min10_abs_diff  \
# 0           32.548285          -0.914081              -1.212743
# 1           32.548285          -0.914081              -1.212743
# 2           32.548285          -0.914081              -1.212743
# 3           32.548285          -0.914081              -1.212743
# 4           32.548285          -0.914081              -1.212743
# 5           32.548285          -0.914081              -1.212743
# 6           32.548285          -0.914081              -1.212743
# 7           32.548285          -0.914081              -1.212743
# 8           32.548285          -0.914081              -1.212743
# 9           32.548285          -0.914081              -1.212743
#
#    v_mean_min5_diff.1
# 0          -32.548285
# 1          -32.548285
# 2          -32.548285
# 3          -32.548285
# 4          -32.548285
# 5          -32.548285
# 6          -32.548285
# 7          -32.548285
# 8          -32.548285
# 9          -32.548285
#
# [10 rows x 81 columns]
