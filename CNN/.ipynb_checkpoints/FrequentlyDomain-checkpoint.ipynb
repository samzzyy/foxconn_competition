# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
import math
import random
import gc

from python_speech_features import logfbank,delta
# Out:
# /usr/local/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def eachFile(filepath):
    pathDir = os.listdir(filepath)
    for filename in pathDir:
        if os.path.splitext(filename)[1] != ".csv":
            pathDir.remove(filename)
    pathDir.sort(key = lambda x: int(x[:-4]))
    path = []
    for allDir in pathDir:
        child = os.path.join('%s%s'%(filepath,allDir))
        path.append(child)
    return path
def load_fbank_feature(train_path,train_floder,sample_rate):
    bug = 0
    fbank_feature = []
    label = []
    for each_floder in train_floder:
        file_set = eachFile(train_path+each_floder+"Sensor1/")
        entire_life = len(file_set)*5
        for each in file_set:
            each_data = pd.read_csv(each)["vibration_1"]
            print(each)
            if len(each_data)%sample_rate != 0:
                leng = len(each_data)//sample_rate 
                each_data = each_data[:leng*sample_rate] ### (60*sample_rate,)
            
            each_data = np.array(each_data)
#             each_data = denose_data(each_data,"db5",3)
            each_data = np.reshape(each_data,(-1,sample_rate))
            for each_sample in each_data:
#                 each_feature = []
                each_fbank_feature = logfbank(each_sample,sample_rate,winlen=0.04,winstep=0.02,
                                              nfft=1024,nfilt=40)
#                 each_d_feature = delta(each_fbank_feature,2)
#                 each_dd_feature = delta(each_d_feature,2)
#                 each_feature = np.column_stack((each_fbank_feature,each_d_feature,each_dd_feature))
#                 each_fbank_feature2 = logfbank(each_sample[:,1],sample_rate,winlen=0.04,winstep=0.02,
# nfft=1024,nfilt=40)
            ### (frames_numbers,feature_num == 40)
#                 each_feature.append(each_fbank_feature1)
#                 each_feature.append(each_fbank_feature2)
                fbank_feature.append(each_fbank_feature)
#                 assert bug == 1,"Debugging"

            index = int(each.split('/')[-1].split('.')[0])
            residual_life = entire_life - index*5
            each_label = np.array([residual_life]*len(each_data))### (leng,)
            each_label = np.reshape(each_label,[-1,1]) ### (leng,1)
            label.extend(each_label)

    fbank_feature = np.array(fbank_feature)
    label = np.array(label)
    print(fbank_feature.shape)
    print(label.shape)
    return fbank_feature,label

# %%
train_path = "../../01-TrainingData-additional/"
train_floder1 = ["01/"]
train_floder2 = ["02/"]
train_floder3 = ["03/"]
sample_rate = 25600

# %%
train_data1,train_label1 = load_fbank_feature(train_path,train_floder1,sample_rate)
train_data2,train_label2 = load_fbank_feature(train_path,train_floder2,sample_rate)
train_data3,train_label3 = load_fbank_feature(train_path,train_floder3,sample_rate)
train_data=np.append(train_data1,train_data2,axis=0)
train_data=np.append(train_data,train_data3,axis=0)
train_label=np.append(train_label1,train_label2,axis=0)
train_label=np.append(train_label,train_label3,axis=0)
valid_data=train_data1
valid_label=train_label1
valid_data=train_data1
valid_label=train_label1
print(train_data.shape,train_label.shape)
print(valid_data.shape,valid_label.shape)
gc.collect()
# Out:
# ../../01-TrainingData-additional/01/Sensor1/1.csv
# ../../01-TrainingData-additional/01/Sensor1/2.csv
# ../../01-TrainingData-additional/01/Sensor1/3.csv
# ../../01-TrainingData-additional/01/Sensor1/4.csv
# ../../01-TrainingData-additional/01/Sensor1/5.csv
# ../../01-TrainingData-additional/01/Sensor1/6.csv
# ../../01-TrainingData-additional/01/Sensor1/7.csv
# ../../01-TrainingData-additional/01/Sensor1/8.csv
# ../../01-TrainingData-additional/01/Sensor1/9.csv
# ../../01-TrainingData-additional/01/Sensor1/10.csv
# ../../01-TrainingData-additional/01/Sensor1/11.csv
# ../../01-TrainingData-additional/01/Sensor1/12.csv
# ../../01-TrainingData-additional/01/Sensor1/13.csv
# ../../01-TrainingData-additional/01/Sensor1/14.csv
# ../../01-TrainingData-additional/01/Sensor1/15.csv
# ../../01-TrainingData-additional/01/Sensor1/16.csv
# ../../01-TrainingData-additional/01/Sensor1/17.csv
# ../../01-TrainingData-additional/01/Sensor1/18.csv
# ../../01-TrainingData-additional/01/Sensor1/19.csv
# ../../01-TrainingData-additional/01/Sensor1/20.csv
# ../../01-TrainingData-additional/01/Sensor1/21.csv
# ../../01-TrainingData-additional/01/Sensor1/22.csv
# ../../01-TrainingData-additional/01/Sensor1/23.csv
# ../../01-TrainingData-additional/01/Sensor1/24.csv
# ../../01-TrainingData-additional/01/Sensor1/25.csv
# ../../01-TrainingData-additional/01/Sensor1/26.csv
# ../../01-TrainingData-additional/01/Sensor1/27.csv
# ../../01-TrainingData-additional/01/Sensor1/28.csv
# ../../01-TrainingData-additional/01/Sensor1/29.csv
# ../../01-TrainingData-additional/01/Sensor1/30.csv
# ../../01-TrainingData-additional/01/Sensor1/31.csv
# ../../01-TrainingData-additional/01/Sensor1/32.csv
# ../../01-TrainingData-additional/01/Sensor1/33.csv
# ../../01-TrainingData-additional/01/Sensor1/34.csv
# ../../01-TrainingData-additional/01/Sensor1/35.csv
# ../../01-TrainingData-additional/01/Sensor1/36.csv
# ../../01-TrainingData-additional/01/Sensor1/37.csv
# ../../01-TrainingData-additional/01/Sensor1/38.csv
# ../../01-TrainingData-additional/01/Sensor1/39.csv
# ../../01-TrainingData-additional/01/Sensor1/40.csv
# ../../01-TrainingData-additional/01/Sensor1/41.csv
# ../../01-TrainingData-additional/01/Sensor1/42.csv
# ../../01-TrainingData-additional/01/Sensor1/43.csv
# ../../01-TrainingData-additional/01/Sensor1/44.csv
# ../../01-TrainingData-additional/01/Sensor1/45.csv
# ../../01-TrainingData-additional/01/Sensor1/46.csv
# ../../01-TrainingData-additional/01/Sensor1/47.csv
# ../../01-TrainingData-additional/01/Sensor1/48.csv
# (2789, 49, 40)
# (2789, 1)
# ../../01-TrainingData-additional/02/Sensor1/1.csv
# ../../01-TrainingData-additional/02/Sensor1/2.csv
# ../../01-TrainingData-additional/02/Sensor1/3.csv
# ../../01-TrainingData-additional/02/Sensor1/4.csv
# ../../01-TrainingData-additional/02/Sensor1/5.csv
# ../../01-TrainingData-additional/02/Sensor1/6.csv
# ../../01-TrainingData-additional/02/Sensor1/7.csv
# ../../01-TrainingData-additional/02/Sensor1/8.csv
# ../../01-TrainingData-additional/02/Sensor1/9.csv
# ../../01-TrainingData-additional/02/Sensor1/10.csv
# ../../01-TrainingData-additional/02/Sensor1/11.csv
# ../../01-TrainingData-additional/02/Sensor1/12.csv
# ../../01-TrainingData-additional/02/Sensor1/13.csv
# ../../01-TrainingData-additional/02/Sensor1/14.csv
# ../../01-TrainingData-additional/02/Sensor1/15.csv
# ../../01-TrainingData-additional/02/Sensor1/16.csv
# ../../01-TrainingData-additional/02/Sensor1/17.csv
# ../../01-TrainingData-additional/02/Sensor1/18.csv
# ../../01-TrainingData-additional/02/Sensor1/19.csv
# ../../01-TrainingData-additional/02/Sensor1/20.csv
# ../../01-TrainingData-additional/02/Sensor1/21.csv
# ../../01-TrainingData-additional/02/Sensor1/22.csv
# ../../01-TrainingData-additional/02/Sensor1/23.csv
# ../../01-TrainingData-additional/02/Sensor1/24.csv
# ../../01-TrainingData-additional/02/Sensor1/25.csv
# ../../01-TrainingData-additional/02/Sensor1/26.csv
# ../../01-TrainingData-additional/02/Sensor1/27.csv
# ../../01-TrainingData-additional/02/Sensor1/28.csv
# ../../01-TrainingData-additional/02/Sensor1/29.csv
# ../../01-TrainingData-additional/02/Sensor1/30.csv
# ../../01-TrainingData-additional/02/Sensor1/31.csv
# ../../01-TrainingData-additional/02/Sensor1/32.csv
# ../../01-TrainingData-additional/02/Sensor1/33.csv
# ../../01-TrainingData-additional/02/Sensor1/34.csv
# ../../01-TrainingData-additional/02/Sensor1/35.csv
# ../../01-TrainingData-additional/02/Sensor1/36.csv
# ../../01-TrainingData-additional/02/Sensor1/37.csv
# ../../01-TrainingData-additional/02/Sensor1/38.csv
# ../../01-TrainingData-additional/02/Sensor1/39.csv
# ../../01-TrainingData-additional/02/Sensor1/40.csv
# ../../01-TrainingData-additional/02/Sensor1/41.csv
# ../../01-TrainingData-additional/02/Sensor1/42.csv
# ../../01-TrainingData-additional/02/Sensor1/43.csv
# ../../01-TrainingData-additional/02/Sensor1/44.csv
# ../../01-TrainingData-additional/02/Sensor1/45.csv
# ../../01-TrainingData-additional/02/Sensor1/46.csv
# ../../01-TrainingData-additional/02/Sensor1/47.csv
# ../../01-TrainingData-additional/02/Sensor1/48.csv
# (2804, 49, 40)
# (2804, 1)
# ../../01-TrainingData-additional/03/Sensor1/1.csv
# ../../01-TrainingData-additional/03/Sensor1/2.csv
# ../../01-TrainingData-additional/03/Sensor1/3.csv
# ../../01-TrainingData-additional/03/Sensor1/4.csv
# ../../01-TrainingData-additional/03/Sensor1/5.csv
# ../../01-TrainingData-additional/03/Sensor1/6.csv
# ../../01-TrainingData-additional/03/Sensor1/7.csv
# ../../01-TrainingData-additional/03/Sensor1/8.csv
# ../../01-TrainingData-additional/03/Sensor1/9.csv
# ../../01-TrainingData-additional/03/Sensor1/10.csv
# ../../01-TrainingData-additional/03/Sensor1/11.csv
# ../../01-TrainingData-additional/03/Sensor1/12.csv
# ../../01-TrainingData-additional/03/Sensor1/13.csv
# ../../01-TrainingData-additional/03/Sensor1/14.csv
# ../../01-TrainingData-additional/03/Sensor1/15.csv
# ../../01-TrainingData-additional/03/Sensor1/16.csv
# ../../01-TrainingData-additional/03/Sensor1/17.csv
# ../../01-TrainingData-additional/03/Sensor1/18.csv
# ../../01-TrainingData-additional/03/Sensor1/19.csv
# ../../01-TrainingData-additional/03/Sensor1/20.csv
# ../../01-TrainingData-additional/03/Sensor1/21.csv
# ../../01-TrainingData-additional/03/Sensor1/22.csv
# ../../01-TrainingData-additional/03/Sensor1/23.csv
# ../../01-TrainingData-additional/03/Sensor1/24.csv
# ../../01-TrainingData-additional/03/Sensor1/25.csv
# ../../01-TrainingData-additional/03/Sensor1/26.csv
# ../../01-TrainingData-additional/03/Sensor1/27.csv
# ../../01-TrainingData-additional/03/Sensor1/28.csv
# ../../01-TrainingData-additional/03/Sensor1/29.csv
# ../../01-TrainingData-additional/03/Sensor1/30.csv
# ../../01-TrainingData-additional/03/Sensor1/31.csv
# ../../01-TrainingData-additional/03/Sensor1/32.csv
# ../../01-TrainingData-additional/03/Sensor1/33.csv
# ../../01-TrainingData-additional/03/Sensor1/34.csv
# ../../01-TrainingData-additional/03/Sensor1/35.csv
# ../../01-TrainingData-additional/03/Sensor1/36.csv
# ../../01-TrainingData-additional/03/Sensor1/37.csv
# (2074, 49, 40)
# (2074, 1)
# (7667, 49, 40) (7667, 1)
# (2789, 49, 40) (2789, 1)
# 721

# %%
miu = np.mean(train_data)
sigma = np.std(train_data)
valid_data = (valid_data-miu)/sigma
train_data  = (train_data - miu)/sigma
train_data = np.reshape(train_data,(-1,49,40,1))
valid_data = np.reshape(valid_data,(-1,49,40,1))
print(train_data.shape,train_label.shape)
print(valid_data.shape,valid_label.shape)
gc.collect()
# Out:
# (7667, 49, 40, 1) (7667, 1)
# (2789, 49, 40, 1) (2789, 1)
# 0

# %%
from keras import models as M
from keras import layers as L
from keras import optimizers
from keras import metrics
import functools
from keras.callbacks import ModelCheckpoint

from keras.callbacks import Callback
graph = None
model = None
# Out:
# Using TensorFlow backend.

# %%
def evaluation_metric(y_true, y_pred):
    y_true, y_pred = tf.reshape(y_true, [-1]), tf.reshape(y_pred, [-1])
    er = y_true - y_pred
    mask_n, mask_p = (er<=0), (er>0)
    er_n, er_p = tf.boolean_mask(er, mask_n), tf.boolean_mask(er, mask_p)
    score_n = tf.exp(-tf.log(0.5)*er_n/5)
    score_p = tf.exp(tf.log(0.5)*er_p/20)
    score = tf.concat([score_n, score_p], 0)
    score = tf.reduce_mean(score)*100
    return score
def cust_loss(y_real,y_predicted):
    y_diff = y_real - y_predicted
    loss = tf.where(tf.greater(y_diff, 0),
                    -tf.exp(tf.log(0.5) * (y_diff / 20)) +1,
                    -tf.exp(-tf.log(0.5) * (y_diff / 5)) +1)
    return loss*tf.reduce_max(abs(y_diff))

# %%
import matplotlib.pyplot as plt
def plt_plot(y_real,y_predicted):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(range(len(y_real)),y_real, color='g')
    ax.plot(range(len(y_predicted)),y_predicted,color='r')
    plt.show()
def Error_compute(y_real,y_predicted):
    y_diff=y_real-y_predicted
    diff_positive=y_diff[y_diff>0]
    diff_negitive_0=y_diff[y_diff<=0]
    if diff_negitive_0.shape[0] >0:
        sum_negitive_error=sum(np.exp(-np.log(0.5)*(diff_negitive_0/5)))
    else:
        sum_negitive_error=0
    if diff_positive.shape[0] >0:
        sum_positive_error=sum(np.exp(np.log(0.5)*(diff_positive/20)))
    else:
        sum_positive_error=0
    return (sum_negitive_error+sum_positive_error)/len(y_real)

# %%
def model_CNN(input_shape):
    x_input = L.Input(shape=input_shape)
    print(x_input.shape)
#     x = L.BatchNormalization(axis=3)(x_input)
    x = L.Conv2D(16,(3,3),activation='relu')(x_input)
    x = L.MaxPool2D((3,3),strides=(2,2))(x)
    x = L.Conv2D(32,(3,3),activation='relu')(x)
    x = L.Conv2D(32,(3,3),activation='relu')(x)
    x = L.MaxPool2D((3,3),strides=(2,2))(x)
    x = L.Conv2D(64,(3,3),activation='relu')(x)
#     x = L.MaxPool2D((3,3),strides=(2,2))(x)
    x = L.Flatten()(x)
    x = L.Dense(512,activation="relu")(x)
    x = L.Dense(1024,activation="relu")(x)
#     x = L.Dropout(0.5)(x)

    y = L.Dense(1)(x)
    
    model = M.Model(inputs=x_input, outputs=y, name="VGG_CNN")
    return model

# %%
checkpoint = ModelCheckpoint(filepath="./2conv+2fc+denose.h5",monitor='val_evaluation_metric',verbose=1,save_best_only='True',
                             mode='max',period=1)
# tensorboard = TensorBoard(log_dir='log(./)')
callback_lists = [checkpoint]  #因为callback是list型,必须转化为list
graph = tf.get_default_graph()
model = model_CNN((49,40,1))
model.summary()
# Out:
# (?, 49, 40, 1)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 49, 40, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 38, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 18, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 21, 16, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 19, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 6, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 4, 64)          18496
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1792)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               918016
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 1,476,897
# Trainable params: 1,476,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
Adam = optimizers.Adam(lr=5e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(optimizer=Adam, loss=cust_loss, metrics=[evaluation_metric])
history = model.fit(train_data, train_label, batch_size=16, epochs=100,verbose=1,validation_data=(valid_data, valid_label),
          callbacks=callback_lists)
# Out:
# Train on 7667 samples, validate on 2789 samples
# Epoch 1/100
# 7667/7667 [==============================] - 12s 2ms/step - loss: 107.1533 - evaluation_metric: 17.9269 - val_loss: 61.9113 - val_evaluation_metric: 20.5160
#
# Epoch 00001: val_evaluation_metric improved from -inf to 20.51597, saving model to ./2conv+2fc+denose.h5
# Epoch 2/100
# 7667/7667 [==============================] - 4s 515us/step - loss: 90.0280 - evaluation_metric: 19.5352 - val_loss: 72.1718 - val_evaluation_metric: 16.9494
#
# Epoch 00002: val_evaluation_metric did not improve from 20.51597
# Epoch 3/100
# 7667/7667 [==============================] - 4s 490us/step - loss: 87.3243 - evaluation_metric: 19.5575 - val_loss: 67.2760 - val_evaluation_metric: 17.6103
#
# Epoch 00003: val_evaluation_metric did not improve from 20.51597
# Epoch 4/100
# 7667/7667 [==============================] - 4s 499us/step - loss: 84.5691 - evaluation_metric: 20.0595 - val_loss: 56.5289 - val_evaluation_metric: 24.3360
#
# Epoch 00004: val_evaluation_metric improved from 20.51597 to 24.33595, saving model to ./2conv+2fc+denose.h5
# Epoch 5/100
# 7667/7667 [==============================] - 4s 493us/step - loss: 81.2022 - evaluation_metric: 21.3634 - val_loss: 54.8017 - val_evaluation_metric: 23.2813
#
# Epoch 00005: val_evaluation_metric did not improve from 24.33595
# Epoch 6/100
# 7667/7667 [==============================] - 4s 479us/step - loss: 80.7023 - evaluation_metric: 20.5797 - val_loss: 50.8703 - val_evaluation_metric: 25.9344
#
# Epoch 00006: val_evaluation_metric improved from 24.33595 to 25.93441, saving model to ./2conv+2fc+denose.h5
# Epoch 7/100
# 7667/7667 [==============================] - 4s 479us/step - loss: 71.4391 - evaluation_metric: 23.3541 - val_loss: 48.7085 - val_evaluation_metric: 28.8850
#
# Epoch 00007: val_evaluation_metric improved from 25.93441 to 28.88504, saving model to ./2conv+2fc+denose.h5
# Epoch 8/100
# 7667/7667 [==============================] - 4s 503us/step - loss: 68.8393 - evaluation_metric: 24.9001 - val_loss: 44.8279 - val_evaluation_metric: 30.4436
#
# Epoch 00008: val_evaluation_metric improved from 28.88504 to 30.44359, saving model to ./2conv+2fc+denose.h5
# Epoch 9/100
# 7667/7667 [==============================] - 4s 506us/step - loss: 69.6736 - evaluation_metric: 24.8612 - val_loss: 51.8588 - val_evaluation_metric: 24.5615
#
# Epoch 00009: val_evaluation_metric did not improve from 30.44359
# Epoch 10/100
# 7667/7667 [==============================] - 4s 500us/step - loss: 63.0800 - evaluation_metric: 28.2734 - val_loss: 42.9143 - val_evaluation_metric: 33.0690
#
# Epoch 00010: val_evaluation_metric improved from 30.44359 to 33.06900, saving model to ./2conv+2fc+denose.h5
# Epoch 11/100
# 7667/7667 [==============================] - 4s 504us/step - loss: 63.4535 - evaluation_metric: 27.7026 - val_loss: 54.4175 - val_evaluation_metric: 23.8082
#
# Epoch 00011: val_evaluation_metric did not improve from 33.06900
# Epoch 12/100
# 7667/7667 [==============================] - 4s 466us/step - loss: 57.9492 - evaluation_metric: 29.8966 - val_loss: 54.0281 - val_evaluation_metric: 28.5638
#
# Epoch 00012: val_evaluation_metric did not improve from 33.06900
# Epoch 13/100
# 7667/7667 [==============================] - 4s 495us/step - loss: 56.6100 - evaluation_metric: 31.9505 - val_loss: 40.2250 - val_evaluation_metric: 36.0971
#
# Epoch 00013: val_evaluation_metric improved from 33.06900 to 36.09710, saving model to ./2conv+2fc+denose.h5
# Epoch 14/100
# 7667/7667 [==============================] - 4s 499us/step - loss: 53.0996 - evaluation_metric: 33.4707 - val_loss: 37.3767 - val_evaluation_metric: 39.5004
#
# Epoch 00014: val_evaluation_metric improved from 36.09710 to 39.50041, saving model to ./2conv+2fc+denose.h5
# Epoch 15/100
# 7667/7667 [==============================] - 4s 506us/step - loss: 52.9232 - evaluation_metric: 33.6918 - val_loss: 40.1538 - val_evaluation_metric: 37.2214
#
# Epoch 00015: val_evaluation_metric did not improve from 39.50041
# Epoch 16/100
# 7667/7667 [==============================] - 4s 501us/step - loss: 52.2280 - evaluation_metric: 33.7683 - val_loss: 38.4434 - val_evaluation_metric: 39.2114
#
# Epoch 00016: val_evaluation_metric did not improve from 39.50041
# Epoch 17/100
# 7667/7667 [==============================] - 4s 509us/step - loss: 52.0184 - evaluation_metric: 34.3514 - val_loss: 34.1840 - val_evaluation_metric: 38.5390
#
# Epoch 00017: val_evaluation_metric did not improve from 39.50041
# Epoch 18/100
# 7667/7667 [==============================] - 4s 485us/step - loss: 50.2881 - evaluation_metric: 34.6197 - val_loss: 43.2338 - val_evaluation_metric: 27.8869
#
# Epoch 00018: val_evaluation_metric did not improve from 39.50041
# Epoch 19/100
# 7667/7667 [==============================] - 4s 462us/step - loss: 50.1595 - evaluation_metric: 34.7115 - val_loss: 35.6637 - val_evaluation_metric: 42.2049
#
# Epoch 00019: val_evaluation_metric improved from 39.50041 to 42.20488, saving model to ./2conv+2fc+denose.h5
# Epoch 20/100
# 7667/7667 [==============================] - 4s 503us/step - loss: 50.3658 - evaluation_metric: 34.6836 - val_loss: 50.2556 - val_evaluation_metric: 30.8883
#
# Epoch 00020: val_evaluation_metric did not improve from 42.20488
# Epoch 21/100
# 7667/7667 [==============================] - 4s 500us/step - loss: 50.2207 - evaluation_metric: 34.4831 - val_loss: 38.5734 - val_evaluation_metric: 39.0051
#
# Epoch 00021: val_evaluation_metric did not improve from 42.20488
# Epoch 22/100
# 7667/7667 [==============================] - 4s 501us/step - loss: 49.3603 - evaluation_metric: 35.3066 - val_loss: 34.0166 - val_evaluation_metric: 43.6616
#
# Epoch 00022: val_evaluation_metric improved from 42.20488 to 43.66164, saving model to ./2conv+2fc+denose.h5
# Epoch 23/100
# 7667/7667 [==============================] - 4s 499us/step - loss: 48.8059 - evaluation_metric: 35.2858 - val_loss: 34.7675 - val_evaluation_metric: 43.8261
#
# Epoch 00023: val_evaluation_metric improved from 43.66164 to 43.82613, saving model to ./2conv+2fc+denose.h5
# Epoch 24/100
# 7667/7667 [==============================] - 4s 496us/step - loss: 48.2026 - evaluation_metric: 35.8223 - val_loss: 36.6081 - val_evaluation_metric: 41.2623
#
# Epoch 00024: val_evaluation_metric did not improve from 43.82613
# Epoch 25/100
# 7667/7667 [==============================] - 3s 452us/step - loss: 47.8643 - evaluation_metric: 36.4435 - val_loss: 35.8031 - val_evaluation_metric: 43.9961
#
# Epoch 00025: val_evaluation_metric improved from 43.82613 to 43.99615, saving model to ./2conv+2fc+denose.h5
# Epoch 26/100
# 7667/7667 [==============================] - 4s 483us/step - loss: 46.0094 - evaluation_metric: 36.5616 - val_loss: 32.3381 - val_evaluation_metric: 44.7397
#
# Epoch 00026: val_evaluation_metric improved from 43.99615 to 44.73968, saving model to ./2conv+2fc+denose.h5
# Epoch 27/100
# 7667/7667 [==============================] - 4s 490us/step - loss: 45.9085 - evaluation_metric: 36.8679 - val_loss: 28.1502 - val_evaluation_metric: 47.5369
#
# Epoch 00027: val_evaluation_metric improved from 44.73968 to 47.53693, saving model to ./2conv+2fc+denose.h5
# Epoch 28/100
# 7667/7667 [==============================] - 4s 476us/step - loss: 47.3481 - evaluation_metric: 35.7846 - val_loss: 31.9949 - val_evaluation_metric: 45.5860
#
# Epoch 00028: val_evaluation_metric did not improve from 47.53693
# Epoch 29/100
# 7667/7667 [==============================] - 4s 489us/step - loss: 45.3749 - evaluation_metric: 36.5840 - val_loss: 37.0466 - val_evaluation_metric: 39.6493
#
# Epoch 00029: val_evaluation_metric did not improve from 47.53693
# Epoch 30/100
# 7667/7667 [==============================] - 4s 491us/step - loss: 46.0647 - evaluation_metric: 36.7611 - val_loss: 44.5584 - val_evaluation_metric: 29.6300
#
# Epoch 00030: val_evaluation_metric did not improve from 47.53693
# Epoch 31/100
# 7667/7667 [==============================] - 4s 459us/step - loss: 44.4568 - evaluation_metric: 37.3098 - val_loss: 34.5906 - val_evaluation_metric: 42.8339
#
# Epoch 00031: val_evaluation_metric did not improve from 47.53693
# Epoch 32/100
# 7667/7667 [==============================] - 4s 487us/step - loss: 44.4345 - evaluation_metric: 37.2185 - val_loss: 38.1011 - val_evaluation_metric: 39.5329
#
# Epoch 00032: val_evaluation_metric did not improve from 47.53693
# Epoch 33/100
# 7667/7667 [==============================] - 4s 511us/step - loss: 44.2657 - evaluation_metric: 37.1980 - val_loss: 40.3380 - val_evaluation_metric: 37.9273
#
# Epoch 00033: val_evaluation_metric did not improve from 47.53693
# Epoch 34/100
# 7667/7667 [==============================] - 4s 517us/step - loss: 45.7186 - evaluation_metric: 37.2976 - val_loss: 32.3775 - val_evaluation_metric: 45.0786
#
# Epoch 00034: val_evaluation_metric did not improve from 47.53693
# Epoch 35/100
# 7667/7667 [==============================] - 4s 511us/step - loss: 44.4394 - evaluation_metric: 37.4616 - val_loss: 34.0702 - val_evaluation_metric: 42.6236
#
# Epoch 00035: val_evaluation_metric did not improve from 47.53693
# Epoch 36/100
# 7667/7667 [==============================] - 4s 493us/step - loss: 43.7204 - evaluation_metric: 37.9072 - val_loss: 39.7331 - val_evaluation_metric: 38.8972
#
# Epoch 00036: val_evaluation_metric did not improve from 47.53693
# Epoch 37/100
# 7667/7667 [==============================] - 4s 487us/step - loss: 43.5319 - evaluation_metric: 38.1754 - val_loss: 39.0270 - val_evaluation_metric: 38.8242
#
# Epoch 00037: val_evaluation_metric did not improve from 47.53693
# Epoch 38/100
# 7667/7667 [==============================] - 4s 490us/step - loss: 43.2875 - evaluation_metric: 38.3475 - val_loss: 42.6091 - val_evaluation_metric: 36.3470
#
# Epoch 00038: val_evaluation_metric did not improve from 47.53693
# Epoch 39/100
# 7667/7667 [==============================] - 4s 509us/step - loss: 44.8392 - evaluation_metric: 36.9737 - val_loss: 34.0914 - val_evaluation_metric: 43.8129
#
# Epoch 00039: val_evaluation_metric did not improve from 47.53693
# Epoch 40/100
# 7667/7667 [==============================] - 4s 506us/step - loss: 43.9234 - evaluation_metric: 37.4315 - val_loss: 31.8930 - val_evaluation_metric: 45.4756
#
# Epoch 00040: val_evaluation_metric did not improve from 47.53693
# Epoch 41/100
# 7667/7667 [==============================] - 4s 510us/step - loss: 43.5637 - evaluation_metric: 37.4806 - val_loss: 34.0082 - val_evaluation_metric: 40.8119
#
# Epoch 00041: val_evaluation_metric did not improve from 47.53693
# Epoch 42/100
# 7667/7667 [==============================] - 4s 506us/step - loss: 44.2150 - evaluation_metric: 37.7678 - val_loss: 30.2909 - val_evaluation_metric: 47.2119
#
# Epoch 00042: val_evaluation_metric did not improve from 47.53693
# Epoch 43/100
# 7667/7667 [==============================] - 4s 505us/step - loss: 41.9544 - evaluation_metric: 38.8763 - val_loss: 35.6174 - val_evaluation_metric: 41.6775
#
# Epoch 00043: val_evaluation_metric did not improve from 47.53693
# Epoch 44/100
# 7667/7667 [==============================] - 4s 474us/step - loss: 41.4327 - evaluation_metric: 38.9721 - val_loss: 30.0619 - val_evaluation_metric: 46.6014
#
# Epoch 00044: val_evaluation_metric did not improve from 47.53693
# Epoch 45/100
# 7667/7667 [==============================] - 4s 508us/step - loss: 41.1982 - evaluation_metric: 38.9917 - val_loss: 40.3905 - val_evaluation_metric: 38.4709
#
# Epoch 00045: val_evaluation_metric did not improve from 47.53693
# Epoch 46/100
# 7667/7667 [==============================] - 4s 511us/step - loss: 41.8367 - evaluation_metric: 38.6657 - val_loss: 33.2447 - val_evaluation_metric: 44.7887
#
# Epoch 00046: val_evaluation_metric did not improve from 47.53693
# Epoch 47/100
# 7667/7667 [==============================] - 4s 514us/step - loss: 41.9572 - evaluation_metric: 39.0827 - val_loss: 30.4559 - val_evaluation_metric: 47.1900
#
# Epoch 00047: val_evaluation_metric did not improve from 47.53693
# Epoch 48/100
# 7667/7667 [==============================] - 4s 495us/step - loss: 41.1908 - evaluation_metric: 39.4192 - val_loss: 29.7963 - val_evaluation_metric: 47.4517
#
# Epoch 00048: val_evaluation_metric did not improve from 47.53693
# Epoch 49/100
# 7667/7667 [==============================] - 4s 496us/step - loss: 40.8179 - evaluation_metric: 39.7111 - val_loss: 40.5581 - val_evaluation_metric: 38.8087
#
# Epoch 00049: val_evaluation_metric did not improve from 47.53693
# Epoch 50/100
# 7667/7667 [==============================] - 4s 459us/step - loss: 40.4669 - evaluation_metric: 39.7111 - val_loss: 30.5963 - val_evaluation_metric: 46.3204
#
# Epoch 00050: val_evaluation_metric did not improve from 47.53693
# Epoch 51/100
# 7667/7667 [==============================] - 4s 495us/step - loss: 39.1686 - evaluation_metric: 39.4239 - val_loss: 27.9471 - val_evaluation_metric: 47.5282
#
# Epoch 00051: val_evaluation_metric did not improve from 47.53693
# Epoch 52/100
# 7667/7667 [==============================] - 4s 498us/step - loss: 41.1747 - evaluation_metric: 39.3178 - val_loss: 33.7579 - val_evaluation_metric: 44.1902
#
# Epoch 00052: val_evaluation_metric did not improve from 47.53693
# Epoch 53/100
# 7667/7667 [==============================] - 4s 522us/step - loss: 40.8878 - evaluation_metric: 39.0756 - val_loss: 33.6857 - val_evaluation_metric: 43.2074
#
# Epoch 00053: val_evaluation_metric did not improve from 47.53693
# Epoch 54/100
# 7667/7667 [==============================] - 4s 495us/step - loss: 39.6317 - evaluation_metric: 39.5741 - val_loss: 27.0324 - val_evaluation_metric: 48.2248
#
# Epoch 00054: val_evaluation_metric improved from 47.53693 to 48.22478, saving model to ./2conv+2fc+denose.h5
# Epoch 55/100
# 7667/7667 [==============================] - 4s 506us/step - loss: 40.0193 - evaluation_metric: 39.7493 - val_loss: 28.5489 - val_evaluation_metric: 47.5548
#
# Epoch 00055: val_evaluation_metric did not improve from 48.22478
# Epoch 56/100
# 7667/7667 [==============================] - 4s 477us/step - loss: 39.6008 - evaluation_metric: 39.8069 - val_loss: 47.6901 - val_evaluation_metric: 33.2274
#
# Epoch 00056: val_evaluation_metric did not improve from 48.22478
# Epoch 57/100
# 7667/7667 [==============================] - 4s 482us/step - loss: 40.1319 - evaluation_metric: 39.4829 - val_loss: 28.9069 - val_evaluation_metric: 48.1526
#
# Epoch 00057: val_evaluation_metric did not improve from 48.22478
# Epoch 58/100
# 7667/7667 [==============================] - 4s 482us/step - loss: 39.6741 - evaluation_metric: 39.8568 - val_loss: 36.1660 - val_evaluation_metric: 41.1011
#
# Epoch 00058: val_evaluation_metric did not improve from 48.22478
# Epoch 59/100
# 7667/7667 [==============================] - 4s 508us/step - loss: 38.9521 - evaluation_metric: 39.9933 - val_loss: 30.1599 - val_evaluation_metric: 46.2763
#
# Epoch 00059: val_evaluation_metric did not improve from 48.22478
# Epoch 60/100
# 7667/7667 [==============================] - 4s 509us/step - loss: 39.7881 - evaluation_metric: 39.7246 - val_loss: 28.9630 - val_evaluation_metric: 45.2367
#
# Epoch 00060: val_evaluation_metric did not improve from 48.22478
# Epoch 61/100
# 7667/7667 [==============================] - 4s 513us/step - loss: 39.5523 - evaluation_metric: 40.4860 - val_loss: 33.9387 - val_evaluation_metric: 43.9708
#
# Epoch 00061: val_evaluation_metric did not improve from 48.22478
# Epoch 62/100
# 7667/7667 [==============================] - 4s 508us/step - loss: 37.9619 - evaluation_metric: 40.6576 - val_loss: 29.6636 - val_evaluation_metric: 46.8486
#
# Epoch 00062: val_evaluation_metric did not improve from 48.22478
# Epoch 63/100
# 7667/7667 [==============================] - 3s 455us/step - loss: 37.3978 - evaluation_metric: 40.9568 - val_loss: 26.7955 - val_evaluation_metric: 49.8979
#
# Epoch 00063: val_evaluation_metric improved from 48.22478 to 49.89793, saving model to ./2conv+2fc+denose.h5
# Epoch 64/100
# 7667/7667 [==============================] - 4s 495us/step - loss: 38.3313 - evaluation_metric: 40.4485 - val_loss: 29.1798 - val_evaluation_metric: 48.1036
#
# Epoch 00064: val_evaluation_metric did not improve from 49.89793
# Epoch 65/100
# 7667/7667 [==============================] - 4s 508us/step - loss: 38.3870 - evaluation_metric: 40.7901 - val_loss: 31.6607 - val_evaluation_metric: 45.2458
#
# Epoch 00065: val_evaluation_metric did not improve from 49.89793
# Epoch 66/100
# 7667/7667 [==============================] - 4s 510us/step - loss: 37.8535 - evaluation_metric: 40.2103 - val_loss: 27.8011 - val_evaluation_metric: 47.9939
#
# Epoch 00066: val_evaluation_metric did not improve from 49.89793
# Epoch 67/100
# 7667/7667 [==============================] - 4s 499us/step - loss: 38.1533 - evaluation_metric: 40.8621 - val_loss: 27.3419 - val_evaluation_metric: 49.0739
#
# Epoch 00067: val_evaluation_metric did not improve from 49.89793
# Epoch 68/100
# 7667/7667 [==============================] - 4s 493us/step - loss: 36.2705 - evaluation_metric: 41.2575 - val_loss: 27.0899 - val_evaluation_metric: 49.1605
#
# Epoch 00068: val_evaluation_metric did not improve from 49.89793
# Epoch 69/100
# 7667/7667 [==============================] - 4s 461us/step - loss: 37.5096 - evaluation_metric: 40.7619 - val_loss: 27.7426 - val_evaluation_metric: 46.1459
#
# Epoch 00069: val_evaluation_metric did not improve from 49.89793
# Epoch 70/100
# 7667/7667 [==============================] - 4s 498us/step - loss: 37.4589 - evaluation_metric: 40.5928 - val_loss: 29.0121 - val_evaluation_metric: 46.4572
#
# Epoch 00070: val_evaluation_metric did not improve from 49.89793
# Epoch 71/100
# 7667/7667 [==============================] - 4s 502us/step - loss: 36.6303 - evaluation_metric: 41.4578 - val_loss: 30.3164 - val_evaluation_metric: 46.1695
#
# Epoch 00071: val_evaluation_metric did not improve from 49.89793
# Epoch 72/100
# 7667/7667 [==============================] - 4s 501us/step - loss: 36.9356 - evaluation_metric: 40.6578 - val_loss: 27.7237 - val_evaluation_metric: 48.0618
#
# Epoch 00072: val_evaluation_metric did not improve from 49.89793
# Epoch 73/100
# 7667/7667 [==============================] - 4s 503us/step - loss: 38.2067 - evaluation_metric: 40.8749 - val_loss: 34.1620 - val_evaluation_metric: 42.2080
#
# Epoch 00073: val_evaluation_metric did not improve from 49.89793
# Epoch 74/100
# 7667/7667 [==============================] - 4s 508us/step - loss: 40.3895 - evaluation_metric: 40.1681 - val_loss: 27.9846 - val_evaluation_metric: 46.6528
#
# Epoch 00074: val_evaluation_metric did not improve from 49.89793
# Epoch 75/100
# 7667/7667 [==============================] - 4s 473us/step - loss: 36.6023 - evaluation_metric: 41.0709 - val_loss: 30.3641 - val_evaluation_metric: 45.4843
#
# Epoch 00075: val_evaluation_metric did not improve from 49.89793
# Epoch 76/100
# 7667/7667 [==============================] - 4s 507us/step - loss: 36.2151 - evaluation_metric: 41.3015 - val_loss: 30.2882 - val_evaluation_metric: 46.7315
#
# Epoch 00076: val_evaluation_metric did not improve from 49.89793
# Epoch 77/100
# 7667/7667 [==============================] - 4s 508us/step - loss: 35.5596 - evaluation_metric: 41.2109 - val_loss: 32.1269 - val_evaluation_metric: 40.0788
#
# Epoch 00077: val_evaluation_metric did not improve from 49.89793
# Epoch 78/100
# 7667/7667 [==============================] - 4s 498us/step - loss: 36.2876 - evaluation_metric: 41.2977 - val_loss: 28.0389 - val_evaluation_metric: 44.3666
#
# Epoch 00078: val_evaluation_metric did not improve from 49.89793
# Epoch 79/100
# 7667/7667 [==============================] - 4s 504us/step - loss: 35.2642 - evaluation_metric: 42.0001 - val_loss: 29.5660 - val_evaluation_metric: 41.4918
#
# Epoch 00079: val_evaluation_metric did not improve from 49.89793
# Epoch 80/100
# 7667/7667 [==============================] - 4s 490us/step - loss: 37.7528 - evaluation_metric: 40.9479 - val_loss: 28.1180 - val_evaluation_metric: 47.3361
#
# Epoch 00080: val_evaluation_metric did not improve from 49.89793
# Epoch 81/100
# 7667/7667 [==============================] - 4s 463us/step - loss: 36.7531 - evaluation_metric: 40.8754 - val_loss: 32.4585 - val_evaluation_metric: 44.4925
#
# Epoch 00081: val_evaluation_metric did not improve from 49.89793
# Epoch 82/100
# 7667/7667 [==============================] - 4s 509us/step - loss: 35.8312 - evaluation_metric: 41.7388 - val_loss: 30.5903 - val_evaluation_metric: 46.0291
#
# Epoch 00082: val_evaluation_metric did not improve from 49.89793
# Epoch 83/100
# 7667/7667 [==============================] - 4s 509us/step - loss: 36.1126 - evaluation_metric: 41.1681 - val_loss: 27.9298 - val_evaluation_metric: 48.1454
#
# Epoch 00083: val_evaluation_metric did not improve from 49.89793
# Epoch 84/100
# 7667/7667 [==============================] - 4s 512us/step - loss: 34.6422 - evaluation_metric: 42.3346 - val_loss: 33.1742 - val_evaluation_metric: 43.5870
#
# Epoch 00084: val_evaluation_metric did not improve from 49.89793
# Epoch 85/100
# 7667/7667 [==============================] - 4s 507us/step - loss: 34.5023 - evaluation_metric: 42.3023 - val_loss: 26.7986 - val_evaluation_metric: 49.1789
#
# Epoch 00085: val_evaluation_metric did not improve from 49.89793
# Epoch 86/100
# 7667/7667 [==============================] - 4s 486us/step - loss: 35.8444 - evaluation_metric: 41.6141 - val_loss: 31.1993 - val_evaluation_metric: 45.2822
#
# Epoch 00086: val_evaluation_metric did not improve from 49.89793
# Epoch 87/100
# 7667/7667 [==============================] - 3s 451us/step - loss: 35.4496 - evaluation_metric: 42.0987 - val_loss: 28.4106 - val_evaluation_metric: 47.8377
#
# Epoch 00087: val_evaluation_metric did not improve from 49.89793
# Epoch 88/100
# 7667/7667 [==============================] - 4s 493us/step - loss: 34.9626 - evaluation_metric: 41.8938 - val_loss: 35.5688 - val_evaluation_metric: 36.4070
#
# Epoch 00088: val_evaluation_metric did not improve from 49.89793
# Epoch 89/100
# 7667/7667 [==============================] - 4s 483us/step - loss: 36.0859 - evaluation_metric: 41.3131 - val_loss: 29.2581 - val_evaluation_metric: 47.1557
#
# Epoch 00089: val_evaluation_metric did not improve from 49.89793
# Epoch 90/100
# 7667/7667 [==============================] - 4s 486us/step - loss: 36.1334 - evaluation_metric: 41.6015 - val_loss: 27.5028 - val_evaluation_metric: 49.6040
#
# Epoch 00090: val_evaluation_metric did not improve from 49.89793
# Epoch 91/100
# 7667/7667 [==============================] - 4s 479us/step - loss: 34.7867 - evaluation_metric: 42.0337 - val_loss: 29.6862 - val_evaluation_metric: 46.9145
#
# Epoch 00091: val_evaluation_metric did not improve from 49.89793
# Epoch 92/100
# 7667/7667 [==============================] - 4s 490us/step - loss: 34.8216 - evaluation_metric: 42.5082 - val_loss: 28.6869 - val_evaluation_metric: 46.8792
#
# Epoch 00092: val_evaluation_metric did not improve from 49.89793
# Epoch 93/100
# 7667/7667 [==============================] - 4s 484us/step - loss: 34.9321 - evaluation_metric: 41.8203 - val_loss: 25.9723 - val_evaluation_metric: 47.8096
#
# Epoch 00093: val_evaluation_metric did not improve from 49.89793
# Epoch 94/100
# 7667/7667 [==============================] - 4s 485us/step - loss: 33.9239 - evaluation_metric: 42.6658 - val_loss: 28.5685 - val_evaluation_metric: 47.6780
#
# Epoch 00094: val_evaluation_metric did not improve from 49.89793
# Epoch 95/100
# 7667/7667 [==============================] - 4s 507us/step - loss: 35.2015 - evaluation_metric: 41.9668 - val_loss: 25.6345 - val_evaluation_metric: 49.8557
#
# Epoch 00095: val_evaluation_metric did not improve from 49.89793
# Epoch 96/100
# 7667/7667 [==============================] - 4s 499us/step - loss: 32.3931 - evaluation_metric: 43.4505 - val_loss: 24.9281 - val_evaluation_metric: 50.7752
#
# Epoch 00096: val_evaluation_metric improved from 49.89793 to 50.77521, saving model to ./2conv+2fc+denose.h5
# Epoch 97/100
# 7667/7667 [==============================] - 4s 503us/step - loss: 34.9902 - evaluation_metric: 42.0950 - val_loss: 25.7381 - val_evaluation_metric: 48.7252
#
# Epoch 00097: val_evaluation_metric did not improve from 50.77521
# Epoch 98/100
# 7667/7667 [==============================] - 4s 502us/step - loss: 35.4755 - evaluation_metric: 42.1043 - val_loss: 25.8041 - val_evaluation_metric: 48.1215
#
# Epoch 00098: val_evaluation_metric did not improve from 50.77521
# Epoch 99/100
# 7667/7667 [==============================] - 4s 474us/step - loss: 34.7534 - evaluation_metric: 42.3666 - val_loss: 35.9790 - val_evaluation_metric: 40.2854
#
# Epoch 00099: val_evaluation_metric did not improve from 50.77521
# Epoch 100/100
# 7667/7667 [==============================] - 4s 467us/step - loss: 34.4652 - evaluation_metric: 42.6457 - val_loss: 40.9186 - val_evaluation_metric: 36.7206
#
# Epoch 00100: val_evaluation_metric did not improve from 50.77521

# %%
gc.collect()
test_index=2
test_path = "../../02-TestingData-keD1/"
test_floder1 = ["00/","01/","02/","03/","04/","05/"]

test_data,test_label = load_fbank_feature(test_path,[test_floder1[test_index]],sample_rate)
miu = np.mean(test_data)
sigma = np.std(test_data)
test_data  = (test_data - miu)/sigma
test_data = np.reshape(test_data,(-1,49,40,1))
print(test_data.shape,test_data.shape)
gc.collect()
# Out:
# ../../02-TestingData-keD1/01/Sensor1/1.csv
# ../../02-TestingData-keD1/01/Sensor1/2.csv
# ../../02-TestingData-keD1/01/Sensor1/3.csv
# ../../02-TestingData-keD1/01/Sensor1/4.csv
# ../../02-TestingData-keD1/01/Sensor1/5.csv
# ../../02-TestingData-keD1/01/Sensor1/6.csv
# ../../02-TestingData-keD1/01/Sensor1/7.csv
# ../../02-TestingData-keD1/01/Sensor1/8.csv
# ../../02-TestingData-keD1/01/Sensor1/9.csv
# ../../02-TestingData-keD1/01/Sensor1/10.csv
# (600, 49, 40)
# (600, 1)
# (600, 49, 40, 1) (600, 49, 40, 1)
# 42

# %%
# from keras.models import load_model
# model = load_model('2conv+2fc+denose.h5',{"evaluation_metric":evaluation_metric})
y_predicted=model.predict(test_data)
plt_plot(test_label,y_predicted)
print(y_predicted.shape)
df_result=pd.DataFrame(np.concatenate((test_label,y_predicted),axis=1),columns=["real","predicted"])
df_predict=df_result["predicted"].groupby(df_result['real']).mean()
err=Error_compute(df_predict.index,df_predict)
# df_predict=df_predict.sort_index(ascending=False)
print(err)
# plt_plot(df_predict.index,df_predict)
df_result.to_csv("%d_cnn_test_predicted.csv"%test_index,index=False)
# Out:
# (600, 1)
# 0.43705372466627174

# %%
y_predicted=model.predict(valid_data)
print(y_predicted.shape)
# 
df_result=pd.DataFrame(np.concatenate((valid_label,y_predicted),axis=1),columns=["real","predicted"])
plt_plot(valid_label,y_predicted)

# %%
df_predict=df_result["predicted"].groupby(df_result['real']).mean()
# df_predict=df_predict
err=Error_compute(df_predict.index,df_predict)
df_predict=df_predict.sort_index(ascending=False)
print(err)
plt_plot(df_predict.index,df_predict)

# %%
df_predicted=pd.DataFrame(y_predicted,columns=['predicted'])
# df_predicted.to_csv("3_cnn_predicted.csv",index=False)
df_predicted.shape

# %%
df_temp1=pd.read_csv("1_cnn_predicted.csv")
print(df_temp1.shape)
df_temp2=pd.read_csv("2_cnn_predicted.csv")
print(df_temp2.shape)
df_temp3=pd.read_csv("3_cnn_predicted.csv")
print(df_temp3.shape)
